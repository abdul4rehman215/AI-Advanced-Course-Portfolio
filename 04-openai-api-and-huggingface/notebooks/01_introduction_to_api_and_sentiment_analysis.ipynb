# %% [markdown]
# <a href="https://colab.research.google.com/github/abdul4rehman215/AI-Advanced-Course-Portfolio/blob/main/04-openai-api-and-huggingface/notebooks/01_introduction_to_api_and_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.30.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import openai

# %%
openai.api_key = '---'

# %%
import openai

openai.api_key = '---'

def Sentiment_analysis(text):
    messages = [
        {"role": "system", "content": """You are trained to analyze and detect the sentiment of the given text.
                                        If you're unsure of an answer, you can say "not sure" and recommend users to review manually."""},
        {"role": "system", "content": f"""Analyze the following text and determine if the sentiment is: positive or negative.
                                          Return answer in single word as either positive or negative: {text}"""}
    ]

    respone = openai.ChatCompletion.create(model="gpt-4",
                                       messages=messages,
                                       max_tokens=1,
                                       n=1,
                                       temparature=0)

    response_text = response.choices[0].message.content.strip().lower()


    return response_text

# %%
import openai

def Sentiment_analysis(text):
    # Initialize the OpenAI client for the new API version
    client = openai.OpenAI(api_key=openai.api_key)

    messages = [
        {"role": "system", "content": """You are trained to analyze and detect the sentiment of the given text.
                                        If you're unsure of an answer, you can say "not sure" and recommend users to review manually."""},
        {"role": "system", "content": f"""Analyze the following text and determine if the sentiment is: positive or negative.
                                          Return answer in single word as either positive or negative: {text}"""}
    ]

    # Use the new chat completions API
    response = client.chat.completions.create(model="gpt-4",
                                              messages=messages,
                                              max_tokens=1,
                                              n=1,
                                              temperature=0)

    response_text = response.choices[0].message.content.strip().lower()

    return response_text

# calling the function
input = 'I hate fast food'
response = Sentiment_analysis(input)
print(input,': The Sentiment is', response)
# Out:
# I hate fast food : The Sentiment is negative

# %%
def generate_blog(topic):
    messages = [
        {"role": "system", "content": """You are trained to analyze a topic and generate a blog post.
                                        The blog post must contain 1500 to 3000 words (No less than 1500 words)."""},
        {"role": "user", "content": f"""Analyze the topic and generate a blog post. The topic is {topic}
                                        The blog post should contain the following format.
                                        1) Title (Not more than one line).
                                        2) Introduction (Give introducion about the topic)
                                        3) Add an image url relevent to the topic.
                                        4) Add 2/3 subheadings and explain them.
                                        5) Body (should describe the facts and findings)
                                        6) Add an image url relevent to the topic.
                                        7) Add 2/3 subheadings and explain them.
                                        8) General FAQ regarding the topic.
                                        9) Conclusion of the topic. """}
        ]



    response = openai.chat.completions.create(model="gpt-3.5-turbo-16k",
                                              messages=messages,
                                              max_tokens=3000,
                                              n=1,
                                              temperature=0.5)

    response_text = response.choices[0].message.content.strip().lower()

    return response_text

# %%
user_input ="Water Importance in Quran"
blog = generate_blog(user_input)
print(blog)
# Out:
# 1) title: the significance of water in the quran
#
# 2) introduction:
# water is a fundamental element of life, and its importance is emphasized in various religious texts, including the quran. in islamic teachings, water is not only essential for physical sustenance but also holds significant spiritual symbolism. the quran, the holy book of islam, contains numerous verses that highlight the importance of water in creation, purification, and as a symbol of divine mercy and blessings. this blog post delves into the significance of water in the quran and explores the deeper meanings associated with this vital element.
#
# 3) image url:
# ![image](image_url)
#
# 4) the role of water in creation:
# one of the recurring themes in the quran is the role of water in the creation of life on earth. in several verses, water is described as the source of all living things and a crucial element in the sustenance of life. the quran mentions how allah created every living creature from water and emphasizes the miraculous nature of this process. water is seen as a symbol of god's power and creativity in bringing forth life from the primordial waters.
#
# furthermore, water is also associated with the concept of purity and cleanliness in islam. ritual ablution, known as wudu, is a fundamental practice for muslims before performing prayers. this act of washing oneself symbolizes spiritual purification and the removal of impurities before engaging in worship. water is seen as a means of cleansing both the body and the soul, preparing the individual for a state of purity and connection with the divine.
#
# 5) body:
# the quran contains numerous verses that highlight the importance of water in various contexts. for example, in surah al-anbiya (21:30), it is mentioned, "and we made from water every living thing. then will they not believe?" this verse underscores the significance of water as the origin of all life forms and challenges humanity to reflect on the miraculous nature of creation.
#
# additionally, water is often used as a metaphor in the quran to convey deeper spiritual truths. in surah al-furqan (25:48-49), it is stated, "and it is he who sends the winds as good tidings before his mercy until, when they have carried heavy rainclouds, we drive them to a dead land and we send down rain therein and bring forth thereby [some] of all the fruits. thus will we bring forth the dead; perhaps you may be reminded." this passage illustrates how water is a symbol of god's mercy and blessings, rejuvenating the earth and bringing forth life from barren lands.
#
# 6) image url:
# ![image](image_url)
#
# 7) water as a symbol of spiritual purification:
# in islamic teachings, water is not only essential for physical cleansing but also holds profound spiritual significance. the act of performing ablution before prayers is a symbolic ritual that represents purification of the soul and preparation for spiritual communion with allah. the quran emphasizes the importance of maintaining purity in both body and spirit, and water serves as a means to achieve this state of cleanliness.
#
# moreover, water is also associated with the concept of sustenance and provision in the quran. in surah al-mulk (67:30), it is mentioned, "say, 'have you considered: if your water was to become sunken [into the earth], then who could bring you flowing water?'" this verse highlights the dependence of humanity on water for survival and underscores the importance of preserving this precious resource for future generations.
#
# 8) general faq:
# q: what is the significance of water in islamic rituals?
# a: water plays a central role in islamic rituals, such as ablution (wudu) before prayers and purification ceremonies. it symbolizes spiritual cleansing and preparation for acts of worship.
#
# q: how is water viewed in the quran?
# a: water is seen as a vital element in creation, purification, and sustenance in the quran. it is described as the source of all living things and a symbol of divine mercy and blessings.
#
# 9) conclusion:
# in conclusion, the quran places great emphasis on the significance of water as a fundamental element of life and a symbol of spiritual purity and blessings. the verses that reference water highlight its essential role in creation, sustenance, and purification, underscoring the importance of preserving this precious resource. by reflecting on the deeper meanings associated with water in the quran, we can gain a deeper appreciation for this vital element and the divine wisdom behind its existence.

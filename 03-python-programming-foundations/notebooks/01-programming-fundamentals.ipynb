# %%
# Saving and printing the number of students for calculating the total marks
num_students = 26
print(num_students)
# Out:
# 26

# %%
total_sales = 1000.50

# %%
student_name = "A"

# %%
print("Hello world")
# Out:
# Hello world

# %%
# Print variable values
print (num_students)
# Out:
# 26

# %%
# Wrong Varible Declaration
2nd_student = "Alice" # Invalid variable name starting with a number
# Out:
#   File "/tmp/ipykernel_3028/4282583840.py", line 2
#     2nd_student = "Alice" # Invalid variable name starting with a number
#     ^
# SyntaxError: invalid decimal literal

# %%
total-sales = 500.75 # Invalid variable name with a hyphen
# Out:
#   File "/tmp/ipykernel_3028/1412673065.py", line 1
#     total-sales = 500.75 # Invalid variable name with a hyphen
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
if = 10 # Invalid variable name using a reserved keyword
# Out:
#   File "/tmp/ipykernel_3028/2861617567.py", line 1
#     if = 10 # Invalid variable name using a reserved keyword
#        ^
# SyntaxError: invalid syntax

# %%
# Wrong Variable Declarations
print(2nd_student)
print(total-sales)
print(if)
# Out:
#   File "/tmp/ipykernel_3028/4246945150.py", line 2
#     print(2nd_student)
#           ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **2- Data types**

# %%
num = 23

# %%
num
# Out:
# 23

# %%
int num1 = 100
# Out:
#   File "/tmp/ipykernel_3028/2271711845.py", line 1
#     int num1 = 100
#         ^
# SyntaxError: invalid syntax

# %%
course = "Hope to Skills Free AI Course"

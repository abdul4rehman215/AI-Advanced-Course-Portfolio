# %% [markdown]
# <a href="https://colab.research.google.com/github/abdul4rehman215/AI-Advanced-Course-Portfolio/blob/main/03-python-programming-foundations/notebooks/01_programming_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics: Variables and Data Types

# %% [markdown]
# ## 1- Variables

# %%
# Saving and printing the number of students for calculating the total marks
num_students = 26
print(num_students)
# Out:
# 26

# %%
total_sales = 1000.50

# %%
student_name = "A"

# %%
print("Hello world")
# Out:
# Hello world

# %%
# Print variable values
print (num_students)
# Out:
# 26

# %%
# Corrected Variable Declaration
second_student = "Alice" # Valid variable name, cannot start with a number

# %%
total_sales_value = 500.75 # Valid variable name, hyphens are not allowed

# %%
if_value = 10 # Valid variable name, 'if' is a reserved keyword

# %%
# Print corrected variable values
print(second_student)
print(total_sales_value)
print(if_value)
# Out:
# Alice
# 500.75
# 10

# %% [markdown]
# ## 2- Data types

# %%
num = 23

# %%
num
# Out:
# 23

# %%
num1 = 100 # In Python, you don't explicitly declare the type (e.g., 'int')

# %%
course = "Hope to Skills Free AI Course"

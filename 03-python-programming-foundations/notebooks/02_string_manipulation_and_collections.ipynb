# %% [markdown]
# <a href="https://colab.research.google.com/github/abdul4rehman215/AI-Advanced-Course-Portfolio/blob/main/03-python-programming-foundations/notebooks/02_string_manipulation_and_collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hope to skills")
print('Hope to skills')
# Out:
# Hope to skills
# Hope to skills

# %%
a = "Hope to skills more"
print(a)
# Out:
# Hope to skills more

# %%
a = """AI, or Artificical Intelligence, refers to the development and implenetation of computer or machines that can perform tasks that would typically require"""
print(a)
# Out:
# AI, or Artificical Intelligence, refers to the development and implenetation of computer or machines that can perform tasks that would typically require

# %%
a = "drink water as much as you can!"
print(a.upper())
# Out:
# DRINK WATER AS MUCH AS YOU CAN!

# %%
a = "PAANI PILO"
print (a.lower())
# Out:
# paani pilo

# %%
a = " paani pilo "
print(a.strip()) # returns "paani pilo"
# Out:
# paani pilo

# %%
a = "paani pilo"
print(a.replace("paani", "water") )
# Out:
# water pilo

# %%
a = "Ai, dubgaya!, Partyyyyy!!!!!"
print(a.split(",")) # returns ['Ai', ' dubgaya!', ' Partyyyyy!!!!!']
# Out:
# ['Ai', ' dubgaya!', ' Partyyyyy!!!!!']

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(len(thislist))
# Out:
# 3

# %%
# String, int and boolean data types:
list1 = ["apple", "banana", "cherrry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

# %%
# a list with strigns, integers and boolean values:
list1 = ["abc", 34, True, 40, "male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
# Access the first element of list
print(list1[2])
# Out:
# True

# %%
# Access the last element of list
print(list1[-1])
# Out:
# male

# %%
# Slicing
print(list1[0:4])
# Out:
# ['abc', 34, True, 40]

# %%
# Add new element in the list using append
list1.append(6)
print(list1)
# Out:
# ['abc', 34, True, 40, 'male', 6]

# %%
# Replace 34 with 54
list1[1] = 54
print(list1)
# Out:
# ['abc', 54, True, 40, 'male', 6]

# %%
# Tuples
thistuple = ("apple", "banana", "cherry", "apple")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple')

# %%
# Python set
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
print(thisset) # Sets are unordered and do not support indexing. You can check for membership or iterate through them.
print("'apple' in thisset:", 'apple' in thisset)
# Out:
# {'banana', 'cherry', 'apple'}
# 'apple' in thisset: True

# %%
# Python Dictionaries are written with curly brackets, and have keys and values:
# Create and print a dictionary:
thisdict = {"brand": "Ford", "model": "Mustang","year": 1964}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
# print the "brand" value of the dictionary:
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
thisdict["brand"]="pani"

# %%
print(thisdict)
# Out:
# {'brand': 'pani', 'model': 'Mustang', 'year': 1964}
